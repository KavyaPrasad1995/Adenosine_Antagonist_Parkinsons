# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as stats

# %%
import seaborn as sns
from statannot import add_stat_annotation

# %%
ax = sns.boxplot(x='Animal_Code',y='SL',data=df, palette='Set2', width = .4, hue = 'Animal_Code')
ax.set(ylim=(0,3))
ax.set(xlabel='Day 8', ylabel='$BP_{ND}$ (SRTM2)')
ax.set_title('Left striatum')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),
           borderaxespad=0)
add_stat_annotation(ax, x='Animal_Code', y='SL', data=df, box_pairs=[('Vehicle','KW6002')], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)

#swrmplotdenotes the datapoints on the plots. Set axis with the same command as seaborn boxplot. Only then it works.
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Vehicle v.s. KW6002: t-test independent samples with Bonferroni correction, P_val=3.835e-02 stat=2.384e+00
# (<AxesSubplot:title={'center':'Left striatum'}, xlabel='Day 8', ylabel='$BP_{ND}$ (SRTM2)'>,
#  [<statannot.StatResult.StatResult at 0x1bff292ca30>])

# %%
sns.pairplot(df, hue ='Animal_Code')

# %%
sns.set(df,ylim=(0,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-c0ce4bf29629> in <module>
# ----> 1 sns.set(df,ylim=(0,2))
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in set(*args, **kwargs)
#     120 def set(*args, **kwargs):
#     121     """Alias for :func:`set_theme`, which is the preferred interface."""
# --> 122     set_theme(*args, **kwargs)
#     123
#     124
#
# TypeError: set_theme() got an unexpected keyword argument 'ylim'

# %%
ax

# %%
ax = sns.boxplot(x='Animal_Code',y='SR',data=df, palette='Blues', width = .4, hue = 'Animal_Code')
ax.set(ylim=(0,3))
ax.set(xlabel='Day 8', ylabel='$BP_{ND}$ (SRTM2)')
ax.set_title('Right striatum')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),
           borderaxespad=0)
add_stat_annotation(ax, x='Animal_Code', y='SR', data=df, box_pairs=[('Vehicle','KW6002')], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Vehicle v.s. KW6002: t-test independent samples with Bonferroni correction, P_val=4.050e-02 stat=2.352e+00
# (<AxesSubplot:title={'center':'Right striatum'}, xlabel='Day 8', ylabel='$BP_{ND}$ (SRTM2)'>,
#  [<statannot.StatResult.StatResult at 0x1bff150b880>])

# %%
import seaborn as sns
from statannot import add_stat_annotation

# %%
scan2 = pd.read_excel('Scan_1.xlsx', sheet_name = 'Sheet2')

# %%
scan2
# Out:
#    Animal_Code        SL        SR     Ratio
# 0      Vehicle  2.003058  1.799909  0.898581
# 1      Vehicle  1.765952  1.728974  0.979061
# 2      Vehicle  2.059324  1.881553  0.913675
# 3      Vehicle  1.896098  1.881659  0.992385
# 4      Vehicle  1.924370  1.797249  0.933941
# 5      Vehicle  1.232020  1.192383  0.967828
# 6      Vehicle  1.921475  1.755156  0.913442
# 7       KW6002  1.553395  1.423765  0.916551
# 8       KW6002  1.448131  1.324106  0.914356
# 9       KW6002  1.466666  1.476003  1.006366
# 10      KW6002  1.669061  1.559661  0.934454
# 11      KW6002  1.308421  1.249894  0.955269
# 12      KW6002  2.065272  1.952126  0.945215
# 13      KW6002  1.303797  1.080017  0.828363
# 14      KW6002  1.654845  1.346222  0.813503

# %%
bx = sns.boxplot(x='Animal_Code',y='SL',data=scan2, palette='Blues', width = .4, hue = 'Animal_Code')
bx.set(ylim=(0,3))
bx.set(xlabel='Day 22', ylabel='$BP_{ND}$ (SRTM2)')
bx.set_title('Left striatum')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
add_stat_annotation(bx, x='Animal_Code', y='SL', data=scan2, box_pairs=[('Vehicle','KW6002')], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Vehicle v.s. KW6002: t-test independent samples with Bonferroni correction, P_val=6.770e-02 stat=1.993e+00
# (<AxesSubplot:title={'center':'Left striatum'}, xlabel='Day 22', ylabel='$BP_{ND}$ (SRTM2)'>,
#  [<statannot.StatResult.StatResult at 0x1bff26370a0>])

# %%
bx = sns.boxplot(x='Animal_Code',y='SR',data=scan2, palette='Blues', width = .4, hue ='Animal_Code')
bx.set(ylim=(0,3))
bx.set(xlabel='Day 22', ylabel='$BP_{ND}$ (SRTM2)')
bx.set_title('Right striatum')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
add_stat_annotation(bx, x='Animal_Code', y='SR', data = scan2, box_pairs=[('Vehicle','KW6002')], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Vehicle v.s. KW6002: t-test independent samples with Bonferroni correction, P_val=4.086e-02 stat=2.270e+00
# (<AxesSubplot:title={'center':'Right striatum'}, xlabel='Day 22', ylabel='$BP_{ND}$ (SRTM2)'>,
#  [<statannot.StatResult.StatResult at 0x1bff27b9910>])

# %%
th= pd.read_excel('Scan_2.xlsx', sheet_name = 'western_blotting')

# %%
th
# Out:
#   left_striatum_d22  TH/GAPDH  TH/GAPDH.1  TH/GAPDH.2  Mean_ls_d22  \
# 0           Vehicle  1.945947    1.871056    0.685219     1.500741
# 1           Vehicle  0.936143    1.527323    0.649875     1.037780
# 2           Vehicle  1.118045    1.569766    0.595019     1.094277
# 3           Vehicle  0.818481    1.309129    0.140324     0.755978
# 4            KW6002  1.792614    1.429701    0.588057     1.270124
# 5            KW6002  1.537321    1.363655    0.666475     1.189151
# 6            KW6002  3.991943    1.226914    0.548118     1.922325
# 7            KW6002  2.309129    1.394663    0.525261     1.409684
#
#    Unnamed: 5 right_striatum_d22  TH/GAPDH.3  TH/GAPDH.4  TH/GAPDH.5  ...  \
# 0         NaN            Vehicle    0.733283    1.536899    0.899367  ...
# 1         NaN            Vehicle    0.651134    1.745586    0.698937  ...
# 2         NaN            Vehicle    0.875817    1.583331    0.663568  ...
# ...

# %%
bx = sns.boxplot(x='left_striatum_d22',y='Mean_ls_d22',data=th, palette='Blues', width = 0.5, hue= 'left_striatum_d22')
bx.set(ylim=(0,2.5))
bx.set(xlabel='Day 22')
bx.set(ylabel='TH levels relative to GAPDH')
bx.set_title('Left Striatum')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),
           borderaxespad=0)
add_stat_annotation(bx, x='left_striatum_d22',y='Mean_ls_d22',data = th, box_pairs=[('Vehicle','KW6002')], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Vehicle v.s. KW6002: t-test independent samples with Bonferroni correction, P_val=1.703e-01 stat=-1.558e+00
# (<AxesSubplot:title={'center':'Left Striatum'}, xlabel='Day 22', ylabel='TH levels relative to GAPDH'>,
#  [<statannot.StatResult.StatResult at 0x1bff2b72df0>])

# %%
bx = sns.boxplot(x='right_striatum_d22',y='Mean_rs_d22',data=th, palette='Blues', width = 0.5, hue= 'right_striatum_d22')
bx.set(ylim=(0,2.5))
bx.set(xlabel='Day 22')
bx.set(ylabel='TH levels relative to GAPDH')
bx.set_title('Right Striatum')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),
           borderaxespad=0)
add_stat_annotation(bx, x='right_striatum_d22',y='Mean_rs_d22',data = th, box_pairs=[('Vehicle','KW6002')], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Vehicle v.s. KW6002: t-test independent samples with Bonferroni correction, P_val=9.155e-03 stat=-3.782e+00
# (<AxesSubplot:title={'center':'Right Striatum'}, xlabel='Day 22', ylabel='TH levels relative to GAPDH'>,
#  [<statannot.StatResult.StatResult at 0x1bff2ad6460>])

# %%
bx = sns.boxplot(x='left_striatum_d7',y='Mean_ls_d7',data=th, palette='Blues', width = 0.5, hue= 'left_striatum_d7')
bx.set(ylim=(0,2.5))
bx.set(xlabel='Day 7')
bx.set(ylabel='TH levels relative to GAPDH')
bx.set_title('Left Striatum')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),
           borderaxespad=0)
add_stat_annotation(bx, x='left_striatum_d7',y='Mean_ls_d7',data = th, box_pairs=[('Vehicle','KW6002')], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Vehicle v.s. KW6002: t-test independent samples with Bonferroni correction, P_val=1.455e-01 stat=-1.672e+00
# (<AxesSubplot:title={'center':'Left Striatum'}, xlabel='Day 7', ylabel='TH levels relative to GAPDH'>,
#  [<statannot.StatResult.StatResult at 0x1bff2bf7730>])

# %%
bx = sns.boxplot(x='right_striatum_d7',y='Mean_rs_d7',data=th, palette='Blues', width = 0.5, hue= 'right_striatum_d7')
bx.set(ylim=(0,3))
bx.set(xlabel='Day 7')
bx.set(ylabel='TH levels relative to GAPDH')
bx.set_title('Right Striatum')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),
           borderaxespad=0)
add_stat_annotation(bx, x='right_striatum_d7',y='Mean_rs_d7',data = th, box_pairs=[('Vehicle','KW6002')], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Vehicle v.s. KW6002: t-test independent samples with Bonferroni correction, P_val=3.127e-01 stat=-1.102e+00
# (<AxesSubplot:title={'center':'Right Striatum'}, xlabel='Day 7', ylabel='TH levels relative to GAPDH'>,
#  [<statannot.StatResult.StatResult at 0x1bff0e73df0>])

# %%
bp = pd.read_excel('raclopride_th.xlsx', sheet_name = 'day_8_2')

# %%
bp
# Out:
#    Animal_Code  region    values
# 0      Vehicle   SL_d8  1.756039
# 1      Vehicle   SL_d8  1.964755
# 2      Vehicle   SL_d8  1.609669
# 3      Vehicle   SL_d8  1.852143
# 4      Vehicle   SL_d8  1.633030
# 5      Vehicle   SL_d8  2.012771
# 6      Vehicle   SR_d8  1.685745
# 7      Vehicle   SR_d8  1.820870
# 8      Vehicle   SR_d8  1.563183
# 9      Vehicle   SR_d8  1.828029
# 10     Vehicle   SR_d8  1.617228
# 11     Vehicle   SR_d8  1.859423
# 12      KW6002   SL_d8  1.373200
# 13      KW6002   SL_d8  1.668609
# 14      KW6002   SL_d8  1.263314
# 15      KW6002   SL_d8  1.619995
# 16      KW6002   SL_d8  1.633030
# 17      KW6002   SL_d8  1.771637
# 18      KW6002   SR_d8  1.301799
# 19      KW6002   SR_d8  1.580204
# 20      KW6002   SR_d8  1.227704
# 21      KW6002   SR_d8  1.522479
# 22      KW6002   SR_d8  1.617228
# 23      KW6002   SR_d8  1.762017
# 24     Vehicle  SL_d22  2.003058
# 25     Vehicle  SL_d22  1.765952
# 26     Vehicle  SL_d22  2.059324
# ...

# %%
ax = sns.boxplot(x='region', y='values',data = bp,hue = 'Animal_Code', palette ={'Vehicle':'turquoise','KW6002':'lightsalmon'}, width =0.6)
ax = sns.stripplot(x='region', y='values',data = bp,hue = 'Animal_Code', palette ={'Vehicle':'mediumblue','KW6002':'orangered'}, size = 7, dodge =True)
ax.set(ylim=(0,3))
ax.set(xlabel='Striatal Regions at Days 8 and 22', ylabel='$BP_{ND}$ (SRTM2)')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.set_xticklabels(['Day 8 left striatum','Day 8 right striatum','Day 22 left striatum','Day 22 right striatum'])
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
plt.title('B', loc='left')
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d8','Vehicle'),('SL_d8','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SR_d8','Vehicle'),('SR_d8','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d22','Vehicle'),('SL_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SR_d22','Vehicle'),('SR_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d8','Vehicle'),('SR_d8','Vehicle'))], test = 't-test_paired', text_format = 'star',loc='outside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d22','Vehicle'),('SR_d22','Vehicle'))], test = 't-test_paired', text_format = 'star',loc='outside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d8','KW6002'),('SR_d8','KW6002'))], test = 't-test_paired', text_format = 'star',loc='outside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d22','KW6002'),('SR_d22','KW6002'))], test = 't-test_paired', text_format = 'star',loc='outside', verbose=2)
ax = sns.set(font_scale = 1.5)
plt.savefig('Raclo_alldays_violin',bbox_inches = 'tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d8_Vehicle v.s. SL_d8_KW6002: t-test independent samples with Bonferroni correction, P_val=3.835e-02 stat=2.384e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SR_d8_Vehicle v.s. SR_d8_KW6002: t-test independent samples with Bonferroni correction, P_val=4.050e-02 stat=2.352e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d22_Vehicle v.s. SL_d22_KW6002: t-test independent samples with Bonferroni correction, P_val=6.770e-02 stat=1.993e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# ...

# %%
ax = sns.histplot(x='Value',data = bp, hue = 'Animal_Code', multiple = 'dodge', palette = {'Vehicle Left Striatum':'dodgerblue','KW6002 Left Striatum':'darkorange', 'Vehicle Right Striatum':'Royalblue', 'KW6002 Right Striatum':'orangered'})
ax.set(xlabel='$BP_{ND}$ (SRTM2) Day 8')
ax = sns.set(rc={'figure.figsize':(10,10)})
ax = sns.set(font_scale = 1.5)
plt.savefig('raclo_histogram.png',bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-37060610b8c0> in <module>
# ----> 1 ax = sns.histplot(x='Value',data = bp, hue = 'Animal_Code', multiple = 'dodge', palette = {'Vehicle Left Striatum':'dodgerblue','KW6002 Left Striatum':'darkorange', 'Vehicle Right Striatum':'Royalblue', 'KW6002 Right Striatum':'orangered'})
#       2 ax.set(xlabel='$BP_{ND}$ (SRTM2) Day 8')
#       3 ax = sns.set(rc={'figure.figsize':(10,10)})
#       4 ax = sns.set(font_scale = 1.5)
#       5 plt.savefig('raclo_histogram.png',bbox_inches = 'tight')
#
# ...

# %%
bp = pd.read_excel('raclopride_th.xlsx', sheet_name = 'day_22_2')

# %%
ax = sns.histplot(x='Value',data = bp, hue = 'Animal_Code', multiple = 'dodge', palette = {'Vehicle Left Striatum':'dodgerblue','KW6002 Left Striatum':'darkorange', 'Vehicle Right Striatum':'Royalblue', 'KW6002 Right Striatum':'orangered'})
ax.set(xlabel='$BP_{ND}$ (SRTM2) Day 22')
plt.savefig('raclo_histogram22.png',bbox_inches = 'tight')

# %%
ax = sns.histplot(x='Value',data = bp, hue = 'Animal_Code', multiple = 'dodge',palette = {'Vehicle Left Striatum':'dodgerblue','KW6002 Left Striatum':'orange', 'Vehicle Right Striatum':'Royalblue', 'KW6002 Right Striatum':'darkorange'})

# %%
bp.groupby(['region','Animal_Code'])['values'].agg(['mean','std'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-032f4aa2821f> in <module>
# ----> 1 bp.groupby(['region','Animal_Code'])['values'].agg(['mean','std'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
# ...

# %%
bp = pd.read_excel('raclopride_th.xlsx', sheet_name = 'Day8')

# %%
bp
# Out:
#    Animal_Code region    values
# 0      Vehicle  SL_d8  1.756039
# 1      Vehicle  SL_d8  1.964755
# 2      Vehicle  SL_d8  1.609669
# 3      Vehicle  SL_d8  1.852143
# 4      Vehicle  SL_d8  1.633030
# 5      Vehicle  SL_d8  2.012771
# 6       KW6002  SL_d8  1.373200
# 7       KW6002  SL_d8  1.668609
# 8       KW6002  SL_d8  1.263314
# 9       KW6002  SL_d8  1.619995
# 10      KW6002  SL_d8  1.633030
# 11      KW6002  SL_d8  1.771637
# 12     Vehicle  SR_d8  1.685745
# 13     Vehicle  SR_d8  1.820870
# 14     Vehicle  SR_d8  1.563183
# 15     Vehicle  SR_d8  1.828029
# 16     Vehicle  SR_d8  1.617228
# 17     Vehicle  SR_d8  1.859423
# 18      KW6002  SR_d8  1.301799
# 19      KW6002  SR_d8  1.580204
# 20      KW6002  SR_d8  1.227704
# 21      KW6002  SR_d8  1.522479
# 22      KW6002  SR_d8  1.617228
# 23      KW6002  SR_d8  1.762017

# %%
ax = sns.boxplot(x='region',y='values',data = bp, width = 0.6 , hue = 'Animal_Code', palette ='hls')
ax.set(ylim=(0,3))
ax.set(xlabel='Striatal Regions at Days 8', ylabel='$BP_{ND}$ (SRTM2)')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
ax.set_xticklabels(['Left Striatum','Right Striatum'])
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d8','Vehicle'),('SL_d8','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SR_d8','Vehicle'),('SR_d8','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d8','Vehicle'),('SR_d8','Vehicle'))], test = 't-test_paired', text_format = 'star',loc='outside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d8','KW6002'),('SR_d8','KW6002'))], test = 't-test_paired', text_format = 'star',loc='outside', verbose=2)
plt.savefig('Day 8 Raclo',bbox_inches = 'tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d8_Vehicle v.s. SL_d8_KW6002: t-test independent samples with Bonferroni correction, P_val=3.835e-02 stat=2.384e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SR_d8_Vehicle v.s. SR_d8_KW6002: t-test independent samples with Bonferroni correction, P_val=4.050e-02 stat=2.352e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d8_Vehicle v.s. SR_d8_Vehicle: t-test paired samples with Bonferroni correction, P_val=2.670e-02 stat=3.105e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# ...

# %%
bp = pd.read_excel('raclopride_th.xlsx', sheet_name = 'Day22')

# %%
bp
# Out:
#    Animal_Code  region    values
# 0      Vehicle  SL_d22  2.003058
# 1      Vehicle  SL_d22  1.765952
# 2      Vehicle  SL_d22  2.059324
# 3      Vehicle  SL_d22  1.896098
# 4      Vehicle  SL_d22  1.924370
# 5      Vehicle  SL_d22  1.232020
# 6      Vehicle  SL_d22  1.921475
# 7       KW6002  SL_d22  1.553395
# 8       KW6002  SL_d22  1.448131
# 9       KW6002  SL_d22  1.466666
# 10      KW6002  SL_d22  1.669061
# 11      KW6002  SL_d22  1.308421
# 12      KW6002  SL_d22  2.065272
# 13      KW6002  SL_d22  1.303797
# 14      KW6002  SL_d22  1.654845
# 15     Vehicle  SR_d22  1.799909
# 16     Vehicle  SR_d22  1.728974
# 17     Vehicle  SR_d22  1.881553
# 18     Vehicle  SR_d22  1.881659
# 19     Vehicle  SR_d22  1.797249
# 20     Vehicle  SR_d22  1.192383
# 21     Vehicle  SR_d22  1.755156
# 22      KW6002  SR_d22  1.423765
# 23      KW6002  SR_d22  1.324106
# 24      KW6002  SR_d22  1.476003
# 25      KW6002  SR_d22  1.559661
# 26      KW6002  SR_d22  1.249894
# ...

# %%
ax = sns.boxplot(x='region',y='values',data = bp, width = 0.6 , hue = 'Animal_Code', palette ='hls')
ax.set(ylim=(0,3))
ax.set(xlabel='Striatal Regions at Day 22', ylabel='$BP_{ND}$ (SRTM2)')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
ax.set_xticklabels(['Left Striatum','Right Striatum'])
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d22','Vehicle'),('SL_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SR_d22','Vehicle'),('SR_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d22','Vehicle'),('SR_d22','Vehicle'))], test = 't-test_paired', text_format = 'star',loc='outside', verbose=2)
add_stat_annotation(ax, x='region', y='values', hue='Animal_Code', data=bp, box_pairs=[(('SL_d22','KW6002'),('SR_d22','KW6002'))], test = 't-test_paired', text_format = 'star',loc='outside', verbose=2)
plt.savefig('Day 22 Raclo',bbox_inches = 'tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d22_Vehicle v.s. SL_d22_KW6002: t-test independent samples with Bonferroni correction, P_val=6.770e-02 stat=1.993e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SR_d22_Vehicle v.s. SR_d22_KW6002: t-test independent samples with Bonferroni correction, P_val=4.086e-02 stat=2.270e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d22_Vehicle v.s. SR_d22_Vehicle: t-test paired samples with Bonferroni correction, P_val=9.768e-03 stat=3.727e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# ...

# %%
th = pd.read_excel('raclopride_th.xlsx', sheet_name = 'blotting_day7')

# %%
th
# Out:
#    Animal_Code Region    Values
# 0      Vehicle  SL_d7  0.944007
# 1      Vehicle  SL_d7  1.159281
# 2      Vehicle  SL_d7  1.169187
# 3      Vehicle  SL_d7  0.957185
# 4       KW6002  SL_d7  0.884491
# 5       KW6002  SL_d7  1.081818
# 6       KW6002  SL_d7  0.984789
# 7       KW6002  SL_d7  0.924475
# 8      Vehicle  SR_d7  1.120114
# 9      Vehicle  SR_d7  1.101432
# 10     Vehicle  SR_d7  0.935792
# 11     Vehicle  SR_d7  0.696065
# 12      KW6002  SR_d7  1.049641
# 13      KW6002  SR_d7  1.060404
# 14      KW6002  SR_d7  0.995343
# 15      KW6002  SR_d7  1.100920

# %%
th.groupby(['Region','Animal_Code'])['Values'].agg(['mean','std'])
# Out:
#                         mean       std
# Region Animal_Code
# SL_d7  KW6002       0.968893  0.085832
#        Vehicle      1.057415  0.123527
# SR_d7  KW6002       1.051577  0.043507
#        Vehicle      0.963351  0.196505

# %%
stats.ttest_ind(th['Animal_Code'][th['Values'] == 'Vehicle'],
                th['Animal_Code'][th['Values'] == 'KW6002'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-53e4dea2c571> in <module>
# ----> 1 stats.ttest_ind(th['Animal_Code'][th['Values'] == 'Vehicle'],
#       2                 th['Animal_Code'][th['Values'] == 'KW6002'])
#
# NameError: name 'stats' is not defined

# %%
ax = sns.boxplot(x='region',y='Mean',data = th, width = 0.6 , hue = 'Animal_Code', palette ='hls')
ax.yaxis.set_ticks(np.arange(0, 2, 0.5))
ax.set(xlabel='Striatal Regions at Days 7', ylabel='TH levels relative to GAPDH')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
add_stat_annotation(ax, x='region', y='Mean', hue='Animal_Code', data=th, box_pairs=[(('SL_d8','Vehicle'),('SL_d8','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='Mean', hue='Animal_Code', data=th, box_pairs=[(('SR_d8','Vehicle'),('SR_d8','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
plt.savefig('THday07',bbox_inches = 'tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d8_Vehicle v.s. SL_d8_KW6002: t-test independent samples with Bonferroni correction, P_val=2.859e-01 stat=1.171e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SR_d8_Vehicle v.s. SR_d8_KW6002: t-test independent samples with Bonferroni correction, P_val=4.550e-01 stat=-7.985e-01

# %%
th = pd.read_excel('raclopride_th.xlsx', sheet_name = 'blotting_day22')

# %%
th
# Out:
#    Animal_Code  Region    Values
# 0      Vehicle  SL_d22  1.101889
# 1      Vehicle  SL_d22  1.099757
# 2      Vehicle  SL_d22  0.999164
# 3      Vehicle  SL_d22  0.853293
# 4       KW6002  SL_d22  1.008991
# 5       KW6002  SL_d22  1.000885
# 6       KW6002  SL_d22  0.989764
# 7       KW6002  SL_d22  0.999751
# 8      Vehicle  SR_d22  1.057779
# 9      Vehicle  SR_d22  0.924975
# 10     Vehicle  SR_d22  0.893175
# 11     Vehicle  SR_d22  0.910230
# 12      KW6002  SR_d22  1.134673
# 13      KW6002  SR_d22  1.139412
# 14      KW6002  SR_d22  1.052170
# 15      KW6002  SR_d22  1.049379

# %%
th.groupby(['Region','Animal_Code'])['Values'].agg(['mean','std'])
# Out:
#                         mean       std
# Region Animal_Code
# SL_d22 KW6002       0.999848  0.007882
#        Vehicle      1.013526  0.117082
# SR_d22 KW6002       1.093909  0.049857
#        Vehicle      0.946540  0.075289

# %%
ax = sns.boxplot(x='region',y='Mean',data = th, width = 0.6 , hue = 'Animal_Code', palette ='hls')
ax.yaxis.set_ticks(np.arange(0, 2.5, 0.5))
ax.set(xlabel='Striatal Regions at Days 22', ylabel='TH levels relative to GAPDH')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
add_stat_annotation(ax, x='region', y='Mean', hue='Animal_Code', data=th, box_pairs=[(('SL_d22','Vehicle'),('SL_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='region', y='Mean', hue='Animal_Code', data=th, box_pairs=[(('SR_d22','Vehicle'),('SR_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
plt.savefig('THday22',bbox_inches = 'tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d22_Vehicle v.s. SL_d22_KW6002: t-test independent samples with Bonferroni correction, P_val=6.070e-01 stat=-5.426e-01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SR_d22_Vehicle v.s. SR_d22_KW6002: t-test independent samples with Bonferroni correction, P_val=3.055e-03 stat=-4.783e+00

# %%
th = pd.read_excel('raclopride_th.xlsx', sheet_name = 'blotting')

# %%
th
# Out:
#    Animal_Code  Region    Values
# 0      Vehicle   SL_d7  0.944007
# 1      Vehicle   SL_d7  1.159281
# 2      Vehicle   SL_d7  1.169187
# 3      Vehicle   SL_d7  0.957185
# 4       KW6002   SL_d7  0.884491
# 5       KW6002   SL_d7  1.081818
# 6       KW6002   SL_d7  0.984789
# 7       KW6002   SL_d7  0.924475
# 8      Vehicle   SR_d7  1.120114
# 9      Vehicle   SR_d7  1.101432
# 10     Vehicle   SR_d7  0.935792
# 11     Vehicle   SR_d7  0.696065
# 12      KW6002   SR_d7  1.049641
# 13      KW6002   SR_d7  1.060404
# 14      KW6002   SR_d7  0.995343
# 15      KW6002   SR_d7  1.100920
# 16     Vehicle  SL_d22  1.101889
# 17     Vehicle  SL_d22  1.099757
# 18     Vehicle  SL_d22  0.999164
# 19     Vehicle  SL_d22  0.853293
# 20      KW6002  SL_d22  1.008991
# 21      KW6002  SL_d22  1.000885
# 22      KW6002  SL_d22  0.989764
# 23      KW6002  SL_d22  0.999751
# 24     Vehicle  SR_d22  1.057779
# 25     Vehicle  SR_d22  0.924975
# 26     Vehicle  SR_d22  0.893175
# ...

# %%
th.groupby(['Region','Animal_Code'])['Values'].agg(['mean','std'])
# Out:
#                         mean       std
# Region Animal_Code
# SL_d22 KW6002       0.999848  0.007882
#        Vehicle      1.013526  0.117082
# SL_d7  KW6002       0.968893  0.085832
#        Vehicle      1.057415  0.123527
# SR_d22 KW6002       1.093909  0.049857
#        Vehicle      0.946540  0.075289
# SR_d7  KW6002       1.051577  0.043507
#        Vehicle      0.963351  0.196505

# %%
stats.ttest_ind(th['Animal_Code'][th['Values'] == 'Vehicle'],
                th['Animal_Code'][th['Values'] == 'KW6002'])
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
ax = sns.boxplot(x='Region',y='Values',data = th, hue = 'Animal_Code', palette={'Vehicle':'dodgerblue','KW6002':'orange'}, width = 0.6)
ax = sns.stripplot(x='Region',y='Values',data = th, palette={'Vehicle':'mediumblue','KW6002':'orangered'}, size = 7, hue= 'Animal_Code', dodge =True)
ax.set(xlabel='Striatal Regions', ylabel='TH levels relative to GAPDH')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
ax.yaxis.set_ticks(np.arange(0, 2, 0.5))
ax.set_xticklabels(['Left Striatum','Right Striatum','Left Striatum','Right Striatum'])
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SL_d7','Vehicle'),('SL_d7','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SR_d7','Vehicle'),('SR_d7','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SL_d22','Vehicle'),('SL_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SR_d22','Vehicle'),('SR_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
plt.savefig('THday_alldays',bbox_inches = 'tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d7_Vehicle v.s. SL_d7_KW6002: t-test independent samples with Bonferroni correction, P_val=2.838e-01 stat=1.177e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SR_d7_Vehicle v.s. SR_d7_KW6002: t-test independent samples with Bonferroni correction, P_val=4.144e-01 stat=-8.767e-01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d22_Vehicle v.s. SL_d22_KW6002: t-test independent samples with Bonferroni correction, P_val=8.234e-01 stat=2.331e-01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# ...

# %%
ax = sns.boxplot(x='Region',y='Values',data = th, width = 0.6 , hue = 'Animal_Code', palette='tab10')
ax = sns.stripplot(x='Region',y='Values',data = th, palette='tab10', hue= 'Animal_Code', dodge =True)
ax.yaxis.set_ticks(np.arange(0, 2, 0.5))
ax.set(xlabel='Striatal Regions', ylabel='TH levels relative to GAPDH')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
ax.set_xticklabels(['Left Striatum','Right Striatum','Left Striatum','Right Striatum'])
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SL_d7','Vehicle'),('SL_d7','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SR_d7','Vehicle'),('SR_d7','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SL_d22','Vehicle'),('SL_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SR_d22','Vehicle'),('SR_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
plt.savefig('THday_alldays_2',bbox_inches = 'tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d7_Vehicle v.s. SL_d7_KW6002: t-test independent samples with Bonferroni correction, P_val=2.838e-01 stat=1.177e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SR_d7_Vehicle v.s. SR_d7_KW6002: t-test independent samples with Bonferroni correction, P_val=4.144e-01 stat=-8.767e-01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d22_Vehicle v.s. SL_d22_KW6002: t-test independent samples with Bonferroni correction, P_val=8.234e-01 stat=2.331e-01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# ...

# %%
th = pd.read_excel('raclopride_th.xlsx', sheet_name = 'blotting_day22')

# %%
th
# Out:
#    Animal_Code  Region    Values
# 0      Vehicle  SL_d22  1.101889
# 1      Vehicle  SL_d22  1.099757
# 2      Vehicle  SL_d22  0.999164
# 3      Vehicle  SL_d22  0.853293
# 4       KW6002  SL_d22  1.008991
# 5       KW6002  SL_d22  1.000885
# 6       KW6002  SL_d22  0.989764
# 7       KW6002  SL_d22  0.999751
# 8      Vehicle  SR_d22  1.057779
# 9      Vehicle  SR_d22  0.924975
# 10     Vehicle  SR_d22  0.893175
# 11     Vehicle  SR_d22  0.910230
# 12      KW6002  SR_d22  1.134673
# 13      KW6002  SR_d22  1.139412
# 14      KW6002  SR_d22  1.052170
# 15      KW6002  SR_d22  1.049379

# %%
th.groupby(['Region','Animal_Code'])['Values'].agg(['mean','std'])
# Out:
#                         mean       std
# Region Animal_Code
# SL_d22 KW6002       0.999848  0.007882
#        Vehicle      1.013526  0.117082
# SR_d22 KW6002       1.093909  0.049857
#        Vehicle      0.946540  0.075289

# %%
ax = sns.boxplot(x='Region',y='Values',data = th, width = 0.6 , hue = 'Animal_Code', palette ='hls')
ax.yaxis.set_ticks(np.arange(0, 2, 0.5))
ax.set(xlabel='Striatal Regions at Day 22', ylabel='TH levels relative to GAPDH')
plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.25, 1),borderaxespad=0)
ax.set_xticklabels(['Left Striatum','Right Striatum'])
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SL_d22','Vehicle'),('SL_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
add_stat_annotation(ax, x='Region', y='Values', hue='Animal_Code', data=th, box_pairs=[(('SR_d22','Vehicle'),('SR_d22','KW6002'))], test = 't-test_ind', text_format = 'star',loc='inside', verbose=2)
plt.savefig('THday22',bbox_inches = 'tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SL_d22_Vehicle v.s. SL_d22_KW6002: t-test independent samples with Bonferroni correction, P_val=8.234e-01 stat=2.331e-01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SR_d22_Vehicle v.s. SR_d22_KW6002: t-test independent samples with Bonferroni correction, P_val=1.716e-02 stat=-3.264e+00

# %%
stats.ttest_ind(th['Region'][th['Values'] == 'Vehicle'],
                th['Region'][th['Values'] == 'KW6002'])
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
tac = pd.read_excel('raclopride_th.xlsx', sheet_name = 'Scan1_LS')

# %%
tac
# Out:
#      Time(Min)    Group   TAC_SUV
# 0     0.083333  Vehicle  0.001491
# 1     0.250000  Vehicle  0.092982
# 2     0.416667  Vehicle  0.181606
# 3     0.583333  Vehicle  0.882593
# 4     0.750000  Vehicle  1.319036
# ..         ...      ...       ...
# 247  22.500000   KW6002  1.180294
# 248  27.500000   KW6002  1.004443
# 249  35.000000   KW6002  0.840612
# 250  45.000000   KW6002  0.655492
# 251  54.997880   KW6002  0.462279
#
# [252 rows x 3 columns]

# %%
ax = sns.lineplot(data=tac, x='Time(Min)', y='TAC_SUV', hue='Group', err_style='band', ci='sd', palette = {'Vehicle':'blue','KW6002':'orange'}, style="Group", markers=True)
ax.set_xlabel('Time[min]')
ax.set_ylabel('Tracer uptake in left striatum day 8 (SUV)')
plt.legend([],[], frameon=False)
plt.title('A', loc='left')
plt.savefig('Scan1_LS.png')

# %%
tac = pd.read_excel('raclopride_th.xlsx', sheet_name = 'Scan1_RS')

# %%
tac
# Out:
#      Time(Min)    Group   TAC_SUV  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     0.083333  Vehicle  0.000640         NaN         NaN         NaN
# 1     0.250000  Vehicle  0.116347         NaN         NaN         NaN
# 2     0.416667  Vehicle  0.201848         NaN         NaN         NaN
# 3     0.583333  Vehicle  0.770834         NaN         NaN         NaN
# 4     0.750000  Vehicle  1.242030         NaN         NaN         NaN
# ..         ...      ...       ...         ...         ...         ...
# 247  22.500000   KW6002  1.189026         NaN         NaN         NaN
# 248  27.500000   KW6002  1.019117         NaN         NaN         NaN
# 249  35.000000   KW6002  0.771591         NaN         NaN         NaN
# 250  45.000000   KW6002  0.607906         NaN         NaN         NaN
# 251  54.997880   KW6002  0.495605         NaN         NaN         NaN
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# ...

# %%
ax = sns.lineplot(data=tac, x='Time(Min)', y='TAC_SUV', hue='Group', err_style='band', ci='sd', palette = {'Vehicle':'blue','KW6002':'orange'}, style="Group", markers=True)
ax.set_xlabel('Time[min]')
ax.set_ylabel('Tracer uptake in right striatum day 8 (SUV)')
plt.legend(bbox_to_anchor=(1.25, 1),
           borderaxespad=0)
plt.title('B', loc='left')
plt.savefig('Scan1_RS.png')

# %%
tac = pd.read_excel('raclopride_th.xlsx', sheet_name = 'Scan2_LS')

# %%
tac
# Out:
#      Time(Min)    Group   TAC_SUV
# 0     0.083333  Vehicle  0.026981
# 1     0.250000  Vehicle  0.145506
# 2     0.416667  Vehicle  0.542620
# 3     0.583333  Vehicle  1.055319
# 4     0.750000  Vehicle  1.664150
# ..         ...      ...       ...
# 289  22.500000   KW6002  1.387488
# 290  27.500000   KW6002  1.241660
# 291  35.000000   KW6002  0.978373
# 292  45.000000   KW6002  0.799313
# 293  54.997880   KW6002  0.635381
#
# [294 rows x 3 columns]

# %%
ax = sns.lineplot(data=tac, x='Time(Min)', y='TAC_SUV', hue='Group', err_style='band', ci='sd', palette = {'Vehicle':'blue','KW6002':'orange'}, style="Group", markers=True)
ax.set_xlabel('Time[min]')
ax.set_ylabel('Tracer uptake in left striatum day 22 (SUV)')
plt.legend([],[], frameon=False)
plt.title('C', loc='left')
plt.savefig('Scan2_LS.png')

# %%
tac = pd.read_excel('raclopride_th.xlsx', sheet_name = 'Scan2_RS')

# %%
tac
# Out:
#      Time(Min)    Group   TAC_SUV  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     0.083333  Vehicle  0.017348         NaN         NaN         NaN
# 1     0.250000  Vehicle  0.238360         NaN         NaN         NaN
# 2     0.416667  Vehicle  0.462435         NaN         NaN         NaN
# 3     0.583333  Vehicle  1.078650         NaN         NaN         NaN
# 4     0.750000  Vehicle  1.567760         NaN         NaN         NaN
# ..         ...      ...       ...         ...         ...         ...
# 289  22.500000   KW6002  1.235970         NaN         NaN         NaN
# 290  27.500000   KW6002  1.031105         NaN         NaN         NaN
# 291  35.000000   KW6002  0.885003         NaN         NaN         NaN
# 292  45.000000   KW6002  0.665126         NaN         NaN         NaN
# 293  54.997880   KW6002  0.563011         NaN         NaN         NaN
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# ...

# %%
ax = sns.lineplot(data=tac, x='Time(Min)', y='TAC_SUV', hue='Group', err_style='band', ci='sd', palette = {'Vehicle':'blue','KW6002':'orange'}, style="Group", markers=True)
ax.set_xlabel('Time[min]')
ax.set_ylabel('Tracer uptake in right striatum day 22 (SUV)')
plt.legend(bbox_to_anchor=(1.25, 1),
           borderaxespad=0)
plt.title('D', loc='left')
plt.savefig('Scan2_RS.png')
